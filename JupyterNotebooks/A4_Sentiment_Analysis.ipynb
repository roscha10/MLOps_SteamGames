# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Inicialización
#
# Importamos las librerías que nos servirán para poder procesar, visualizar y explorar nuestros datos de manera efectiva, la librería `pandas`, `numpy`, `textblob`,`nltk`.

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import nltk

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Extracción de los datos
#
# Para realizar los análisis requeridos, extraeremos los datos esenciales del conjunto `data_reviews`. Estos datos nos permitirán realizar los análisis requeridos.

# %% [markdown]
# El conjunto de datos **`data_reviews`** contiene información sobre usuarios de Steam que realizan reviews (reseñas que consisten en comentarios) de los juegos que consumen, incluyendo identificadores únicos, URL de perfiles, y fechas de posteo, ediciones, estadísticas de utilidad y recomendaciones sobre juegos específicos

# %%
data_reviews = pd.read_csv('data_reviews_cleaned.csv')

# %%
data_reviews.head(3)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
#
#   reviews_posted  reviews_item_id  \
# 0     2011-11-05             1250
# 1     2014-06-24           251610
# 2            NaN           248820
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
#
#                                       reviews_review        reviews_year
# 0  Simple yet with great replayability. In my opi...                2011
# 1  I know what you think when you see this title ...                2014
# 2  A suitably punishing roguelike platformer.  Wi...  Dato no disponible

# %% [markdown]
# # Análisis de Sentimientos
#
# En la fase de análisis de sentimientos, exploramos la columna crítica de nuestro conjunto de datos en data_reviews: 'reviews'. Nuestro objetivo central es crear una nueva columna llamada 'sentiment_analysis' que reemplace a la columna original 'reviews_review'.
#
# Buscamos asignar puntuaciones numéricas que indiquen si el comentario:
# - Negativo ('0')
# - Neutro o carece de reseña ('1')
# - Positivo ('2')
#
# Para lograrlo, aprovechamos TextBlob, una biblioteca de procesamiento de lenguaje natural en Python, que realiza análisis de sentimientos de manera ágil.
#
# La metodología utilizada implica la toma de un texto de revisión como entrada, utilizando `TextBlob` para calcular la polaridad del sentimiento y luego categorizar la revisión como negativa, neutral o positiva según la polaridad calculada. Los valores de polaridad asignados por TextBlob abarcan un espectro desde [-1] para negativo hasta [1] para positivo, con [0] indicando neutralidad. En este caso, hemos utilizado las polaridades por defecto del modelo, lo que nos brinda un enfoque básico pero efectivo para comprender el sentimiento expresado en las reseñas de los usuarios.

# %%
# Función para asignar polaridades
def assign_sentiment(text):
    if not isinstance(text, str):
        return 1  # Neutral para valores no string

    # Crear un objeto TextBlob para el texto
    analysis = TextBlob(text)

    # Obtener la polaridad del sentimiento
    polarity = analysis.sentiment.polarity
    
    # Clasificar el sentimiento basado en la polaridad
    if polarity > 0.1:
        return 2  # Positivo
    elif polarity < -0.1:
        return 0  # Negativo

    return 1  # Neutral

# Aplicar la función a la columna 'reviews_review' utilizando una función lambda
data_reviews['sentiment_analysis'] = data_reviews['reviews_review'].apply(lambda x: assign_sentiment(x))

# %% [markdown]
# Comenzamos explorando los primeros 15 comentarios de nuestra base de datos. Para evaluar el sentimiento de estos comentarios, confiamos en nuestra propia interpretación y observación de las similitudes con las categorizaciones proporcionadas por la biblioteca de análisis de sentimiento TextBlob.

# %%
for index, row in data_reviews.head(15).iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 0:
# Texto del Review: Simple yet with great replayability. In my opinion does "zombie" hordes and team work better than left 4 dead plus has a global leveling system. Alot of down to earth "zombie" splattering fun for the whole family. Amazed this sort of FPS is so rare.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 1:
# Texto del Review: I know what you think when you see this title "Barbie Dreamhouse Party" but do not be intimidated by it's title, this is easily one of my GOTYs. You don't get any of that cliche game mechanics that all the latest games have, this is simply good core gameplay. Yes, you can't 360 noscope your friends, but what you can do is show them up with your bad ♥♥♥ dance moves and put them to shame as you show them what true fashion and color combinations are.I know this game says for kids but, this is easily for any age range and any age will have a blast playing this.8/8
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 2:
# Texto del Review: A suitably punishing roguelike platformer.  Winning feels good.  Progressive unlocks mean a good slog ending in failure doesn't feel like a waste.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 3:
# Texto del Review: This game... is so fun. The fight sequences have been improved from walking dead. It also includes more of a Sam and Max puzzle solving (some of it in the first episode) and walking dead. The game also gets even more better if you have read the Fables comic books, which are without a doubt, very good. The music is also superb and fit the scenarios very well.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 4:
# Texto del Review: Git gud
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 5:
# Texto del Review: This game is Marvellous.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 6:
# Texto del Review: ZIKA DO BAILE
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 7:
# Texto del Review: BEST GAME IN THE BLOODY WORLD
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 8:
# Texto del Review: Killed the Emperor, nobody cared and got away with it. Accidentally killed a chicken and everybody decided to gang up on me. 10/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 9:
# Texto del Review: love it
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 10:
# Texto del Review: mt bom
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 11:
# Texto del Review: es la rajaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 12:
# Texto del Review: MAGICKA *SNORT* *SNORT*
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 13:
# Texto del Review: Amazing, Non-stop action of blowing stuff to bits, Decapitation and shooting everything you see. With a combination of action, thriller and emmersive gameplay, as well as enviromental challanges (Jump physics). This game will really put your eyes to the test, can you see the enemys before they see you? Cause their are so many!This is the second level of the killing floor, I quote bill LF4D "Son we just crossed the street" But in reality they only moved up an elevator level on genes. What has yet to come as the game is slowly realsed with thrilling and horryfing creations, But who really cares, Let's just blow it up, I invite you to get on the GODAMN KILLING FLOOR, LET'S SHOOT ♥♥♥♥♥ES AND GET PAID! RAHHHHHHHHHHH!
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 14:
# Texto del Review: At first, it looked to me that..."Wow, just another plain game... Minecraft Style I guess..."However, after playing it for almost 2 hours, I've realised that this game...Is nothing like Minecraft in terms on gaming content/adventure.If you've ever wished to get DayZ and want to get a first-hand experience of it, this game will be a great start!I do recommend that you guys play with a friend, and not Single Player (Just yet...)My feeling about this game is that it will become a game that requires intense TeamWork, Co-ordination and communication (Recommend: Use Voice Chat in Steam for the meantime).So for those who feel this game isn't worth playing because it looks boring, please think twice...I would have regretted my choice if I didn't choose to play this game for a while.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0

# %% [markdown]
# Continuando con nuestra exploración de los comentarios en nuestra base de datos, nos enfocamos en los últimos 15 comentarios. Al igual que en la etapa anterior, analizamos estos comentarios en función de nuestras percepciones y comparaciones con las categorizaciones proporcionadas por la biblioteca de análisis de sentimiento TextBlob.

# %%
for index, row in data_reviews.tail(10).iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 58159:
# Texto del Review: I wanted this game to be Controller Supported but anyways this is a good game 7/10 [8/10 for people who are addicts to Trucks and Simulators]
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58160:
# Texto del Review: ,
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58161:
# Texto del Review: A first person game which has no guns, no linear story progression ... and just try to jump in this game, I dare you.Everyone must play this game at some point in their life, for it will consume the rest of it.15/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 58162:
# Texto del Review: Its a great game if your up for a challenge or just want to play a great game
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58163:
# Texto del Review: Normally I would hardly play a lego based game but this one is a bit different as it is a sandbox lego game where the limit is your imagination.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 58164:
# Texto del Review: TF2 is alot of fun and its really good but there is a few errors in the game no singleplayer campaing, theres no free for all, people hack and cheat and after a while you get sick of playing it for a while so for this I dont reccomend it unless you cheat or hack and want to do the same thing over and over again but there a VAC servers witch is good and they stop hackers but I dont think they work. But its still a fun game even if you do play with hackers and the acheivments are easy to get unlike othe games ive played so yeah ill rate it 10/10.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58165:
# Texto del Review: Fun game with friends
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58166:
# Texto del Review: So Fun!! :D
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58167:
# Texto del Review: This game is great. The only thing is,Why cant you buy the stuff in the store from this page??
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58168:
# Texto del Review: DOTA 2.normal skill - 2ez for me>high skill - still 2ez, go harder>very high skill (2hard or harder - you do not like to play there, want fun , etc. You leave the game to receive complaints from the players , and then play on a low priority. after a few tricks you get the "hidden pool" to play with the same people who leave the game just like you. " Who are not able to play the ♥♥♥♥ing game," you know? you play without mistakes , blah blah blah , do everything that depends on you , but ... @_@ kill youself if you leaving winnig games. p.s. Do not leave the game and do not play if you do not want to play , or upset than ever.Bad Game, ty Valve for this ♥♥♥♥ing hidden pool and low priority. GL
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0

# %% [markdown]
# Optamos tambien por seleccionar al azar 20 revisiones de nuestra base de datos. La selección aleatoria garantizó que obtuviéramos una muestra diversa y representativa de comentarios de usuarios sin sesgos preexistentes.

# %%
# Seleccionar 20 reviews aleatorias
random_reviews = data_reviews.sample(n=20, random_state=123)

# Mostrar las reviews seleccionadas
for index, row in random_reviews.iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 25813:
# Texto del Review: WAIT UNTIL ITS ON SALE
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 31082:
# Texto del Review: what the ♥♥♥♥ is wrong with the match queues?? i can't find a match as a 2-man without attempting at least 15 times. fix this ♥♥♥♥ please
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 37938:
# Texto del Review: Best game 10 out of 10 would tap garry again ;)
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 23613:
# Texto del Review: This game is definitely my favourite game. It is also undoubtably Telltale's best game. The style of game this is makes it amazing, it gives you a sense of urgency as you don't have much time to decide on life or death situations. This game offers so many possiblities for different storylines it makes you want to play it as many times as you can to see what is different. Your choices decide how the ending goes down but what choices you make also don't effect what happens in the end. I would always recommend this game.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 49900:
# Texto del Review: Just to note throughout the entire game, you are shooting TalibansPros-Smooth gameplay-Strong and good gun sound effects-Developed along with with DICE-Multiplayer is playable...i guess- DUSTY a.k.a. grizzly adamsCons-Too Generic-Developer =EA-Its a Military FPS-Doesn't live up to the 'Medal of Honor™' name -Crap A.I.-Feels like some COD but just slapped on with the Medal of Honor trademark-No recoil for some weaponsOverall, this name is not good. It does not live up the Medal of Honor name and to be honest from this game onwards, the Medal of Honor games don't get any better. Just get airborne or any of the classics since the new ones are too generic, bland and boring as hell. ...Same goes with COD and Battlefield.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 1440:
# Texto del Review: THis is a very fun game, i played it for a long time and lvled several charachters However, i cannot now play as the space combat crashes my game
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 2335:
# Texto del Review: I Cry Every Time.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 7910:
# Texto del Review: Whoever thought this was a good idea needs to neck themselves. ♥♥♥♥ Daybreak.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 37430:
# Texto del Review: Noice
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 3457:
# Texto del Review: Totally awesome.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 44432:
# Texto del Review: me gustaaa
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 20241:
# Texto del Review: Very enjoyable game with a lot of end game content, also its NOT PAY TO WIN
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 56516:
# Texto del Review: this is fun game to play with friends if i were you ill get it now (t't')
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 56763:
# Texto del Review: While not as groundbreaking as it predecessors, AoE3 nevertheless retains much of the what made 1 and 2 great while also implementing new features. Beautiful graphics coupled with a brilliant Home Cities system ensure that AoEIII lives up forever to be one of the better RTS titles in recent times. The Asian Dynasties expansion pack was definitely the real gem in this pack. A major letdown was the absence of historial campaigns which were a staple of 1 and 2. While the story campaigns weren't awful, they bordered on mediocrity and at times, childishly cliche' and odd, trying to desperately interwine historical events/characters into its plot. Ultimately, being a hardcore Age of Empires fan and a hardcore veteran of AoE2 & Mythology, AoE3 still captured my interest as an alternate RTS choice outside of my Starcraft/C&C sessions. 8.5/10 (Complete Collection), 8/10 - Vanilla, 7/10 - War Chiefs, 9/10 - Asian Dynasties.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 29602:
# Texto del Review: hard to get started with, not recommended for beginers
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 29938:
# Texto del Review:  I REALLY like this game i love the graphics, the story, and the puzzles. If you dont have it i think its up to you to get Broken Age. BUT i think you should get it if you if youre looking for video games to buy on steam.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 49932:
# Texto del Review: Waifu clicker9/11 - IGN
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 286:
# Texto del Review: for an incomplete game to provide this much creativity and fun. cant wait for full release .
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 47577:
# Texto del Review: It's a good game, hitboxes could use a little fine tuneing but aside from that this game works and runs quite well, It has good mechanics for both running, and hiding. Verdict - 8/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 47152:
# Texto del Review: I used to love this game. Then i took a paid mod in the knee.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1

# %% [markdown]
# Para enriquecer aún más nuestro proceso de análisis de sentimiento, decidimos llevar a cabo la prueba de análisis de sentimiento utilizando la biblioteca `NLTK` y luego comparar los resultados con los obntenidos utilizando la libreria de TextBlob

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Descargar los recursos necesarios para NLTK (puedes hacerlo una vez)
# nltk.download('vader_lexicon')

# Crear un objeto SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Función para asignar polaridades
def assign_sentiment(text):
    if not isinstance(text, str):
        return 1  # Neutral para valores no string

    # Obtener la puntuación de sentimiento
    sentiment = sia.polarity_scores(text)
    
    # Clasificar el sentimiento basado en la puntuación compuesta
    compound_score = sentiment['compound']
    if compound_score > 0.3:
        return 2  # Positivo
    elif compound_score < -0.3:
        return 0  # Negativo

    return 1  # Neutral

# Aplicar la función a la columna 'reviews_review' utilizando una función lambda
data_reviews['sentiment_analysis'] = data_reviews['reviews_review'].apply(lambda x: assign_sentiment(x))

# %% [markdown]
# Realizamos las mismas evaluaciones que con la libreria textblob:
#
# Evaluación de las Primeras 15 Revisiones

# %%
for index, row in data_reviews.head(15).iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 0:
# Texto del Review: Simple yet with great replayability. In my opinion does "zombie" hordes and team work better than left 4 dead plus has a global leveling system. Alot of down to earth "zombie" splattering fun for the whole family. Amazed this sort of FPS is so rare.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 1:
# Texto del Review: I know what you think when you see this title "Barbie Dreamhouse Party" but do not be intimidated by it's title, this is easily one of my GOTYs. You don't get any of that cliche game mechanics that all the latest games have, this is simply good core gameplay. Yes, you can't 360 noscope your friends, but what you can do is show them up with your bad ♥♥♥ dance moves and put them to shame as you show them what true fashion and color combinations are.I know this game says for kids but, this is easily for any age range and any age will have a blast playing this.8/8
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 2:
# Texto del Review: A suitably punishing roguelike platformer.  Winning feels good.  Progressive unlocks mean a good slog ending in failure doesn't feel like a waste.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 3:
# Texto del Review: This game... is so fun. The fight sequences have been improved from walking dead. It also includes more of a Sam and Max puzzle solving (some of it in the first episode) and walking dead. The game also gets even more better if you have read the Fables comic books, which are without a doubt, very good. The music is also superb and fit the scenarios very well.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 4:
# Texto del Review: Git gud
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 5:
# Texto del Review: This game is Marvellous.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 6:
# Texto del Review: ZIKA DO BAILE
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 7:
# Texto del Review: BEST GAME IN THE BLOODY WORLD
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 8:
# Texto del Review: Killed the Emperor, nobody cared and got away with it. Accidentally killed a chicken and everybody decided to gang up on me. 10/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 9:
# Texto del Review: love it
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 10:
# Texto del Review: mt bom
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 11:
# Texto del Review: es la rajaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 12:
# Texto del Review: MAGICKA *SNORT* *SNORT*
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 13:
# Texto del Review: Amazing, Non-stop action of blowing stuff to bits, Decapitation and shooting everything you see. With a combination of action, thriller and emmersive gameplay, as well as enviromental challanges (Jump physics). This game will really put your eyes to the test, can you see the enemys before they see you? Cause their are so many!This is the second level of the killing floor, I quote bill LF4D "Son we just crossed the street" But in reality they only moved up an elevator level on genes. What has yet to come as the game is slowly realsed with thrilling and horryfing creations, But who really cares, Let's just blow it up, I invite you to get on the GODAMN KILLING FLOOR, LET'S SHOOT ♥♥♥♥♥ES AND GET PAID! RAHHHHHHHHHHH!
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 14:
# Texto del Review: At first, it looked to me that..."Wow, just another plain game... Minecraft Style I guess..."However, after playing it for almost 2 hours, I've realised that this game...Is nothing like Minecraft in terms on gaming content/adventure.If you've ever wished to get DayZ and want to get a first-hand experience of it, this game will be a great start!I do recommend that you guys play with a friend, and not Single Player (Just yet...)My feeling about this game is that it will become a game that requires intense TeamWork, Co-ordination and communication (Recommend: Use Voice Chat in Steam for the meantime).So for those who feel this game isn't worth playing because it looks boring, please think twice...I would have regretted my choice if I didn't choose to play this game for a while.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2

# %% [markdown]
# Evaluación de las Últimas 15 Revisiones

# %%
for index, row in data_reviews.tail(15).iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 58154:
# Texto del Review: I'll link you to something that will... encourage your urge to buy the game..https://www.youtube.com/watch?v=nuHfVn_cfHU
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58155:
# Texto del Review: Duh...
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58156:
# Texto del Review: Recomendo esse jogo para todos e realmente muito bom
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58157:
# Texto del Review: Animal watching/walking sim 10/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58158:
# Texto del Review: Nice fast paced fps game.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58159:
# Texto del Review: I wanted this game to be Controller Supported but anyways this is a good game 7/10 [8/10 for people who are addicts to Trucks and Simulators]
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58160:
# Texto del Review: ,
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58161:
# Texto del Review: A first person game which has no guns, no linear story progression ... and just try to jump in this game, I dare you.Everyone must play this game at some point in their life, for it will consume the rest of it.15/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58162:
# Texto del Review: Its a great game if your up for a challenge or just want to play a great game
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58163:
# Texto del Review: Normally I would hardly play a lego based game but this one is a bit different as it is a sandbox lego game where the limit is your imagination.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 58164:
# Texto del Review: TF2 is alot of fun and its really good but there is a few errors in the game no singleplayer campaing, theres no free for all, people hack and cheat and after a while you get sick of playing it for a while so for this I dont reccomend it unless you cheat or hack and want to do the same thing over and over again but there a VAC servers witch is good and they stop hackers but I dont think they work. But its still a fun game even if you do play with hackers and the acheivments are easy to get unlike othe games ive played so yeah ill rate it 10/10.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58165:
# Texto del Review: Fun game with friends
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58166:
# Texto del Review: So Fun!! :D
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58167:
# Texto del Review: This game is great. The only thing is,Why cant you buy the stuff in the store from this page??
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 58168:
# Texto del Review: DOTA 2.normal skill - 2ez for me>high skill - still 2ez, go harder>very high skill (2hard or harder - you do not like to play there, want fun , etc. You leave the game to receive complaints from the players , and then play on a low priority. after a few tricks you get the "hidden pool" to play with the same people who leave the game just like you. " Who are not able to play the ♥♥♥♥ing game," you know? you play without mistakes , blah blah blah , do everything that depends on you , but ... @_@ kill youself if you leaving winnig games. p.s. Do not leave the game and do not play if you do not want to play , or upset than ever.Bad Game, ty Valve for this ♥♥♥♥ing hidden pool and low priority. GL
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0

# %% [markdown]
# Análisis de 20 Revisiones Seleccionadas Aleatoriamente

# %%
# Seleccionar 20 revisiones aleatorias
random_reviews = data_reviews.sample(n=20, random_state=123)

# Mostrar las revisiones seleccionadas
for index, row in random_reviews.iterrows():
    review_text = row['reviews_review']
    sentiment = row['sentiment_analysis']
    print(f"Review {index}:")
    print(f"Texto del Review: {review_text}")
    print(f"Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): {sentiment}")
    print("\n")
# Out:
# Review 25813:
# Texto del Review: WAIT UNTIL ITS ON SALE
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 31082:
# Texto del Review: what the ♥♥♥♥ is wrong with the match queues?? i can't find a match as a 2-man without attempting at least 15 times. fix this ♥♥♥♥ please
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 37938:
# Texto del Review: Best game 10 out of 10 would tap garry again ;)
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 23613:
# Texto del Review: This game is definitely my favourite game. It is also undoubtably Telltale's best game. The style of game this is makes it amazing, it gives you a sense of urgency as you don't have much time to decide on life or death situations. This game offers so many possiblities for different storylines it makes you want to play it as many times as you can to see what is different. Your choices decide how the ending goes down but what choices you make also don't effect what happens in the end. I would always recommend this game.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 49900:
# Texto del Review: Just to note throughout the entire game, you are shooting TalibansPros-Smooth gameplay-Strong and good gun sound effects-Developed along with with DICE-Multiplayer is playable...i guess- DUSTY a.k.a. grizzly adamsCons-Too Generic-Developer =EA-Its a Military FPS-Doesn't live up to the 'Medal of Honor™' name -Crap A.I.-Feels like some COD but just slapped on with the Medal of Honor trademark-No recoil for some weaponsOverall, this name is not good. It does not live up the Medal of Honor name and to be honest from this game onwards, the Medal of Honor games don't get any better. Just get airborne or any of the classics since the new ones are too generic, bland and boring as hell. ...Same goes with COD and Battlefield.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 1440:
# Texto del Review: THis is a very fun game, i played it for a long time and lvled several charachters However, i cannot now play as the space combat crashes my game
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 2335:
# Texto del Review: I Cry Every Time.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 0
#
#
# Review 7910:
# Texto del Review: Whoever thought this was a good idea needs to neck themselves. ♥♥♥♥ Daybreak.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 37430:
# Texto del Review: Noice
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 3457:
# Texto del Review: Totally awesome.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 44432:
# Texto del Review: me gustaaa
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 20241:
# Texto del Review: Very enjoyable game with a lot of end game content, also its NOT PAY TO WIN
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 56516:
# Texto del Review: this is fun game to play with friends if i were you ill get it now (t't')
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 56763:
# Texto del Review: While not as groundbreaking as it predecessors, AoE3 nevertheless retains much of the what made 1 and 2 great while also implementing new features. Beautiful graphics coupled with a brilliant Home Cities system ensure that AoEIII lives up forever to be one of the better RTS titles in recent times. The Asian Dynasties expansion pack was definitely the real gem in this pack. A major letdown was the absence of historial campaigns which were a staple of 1 and 2. While the story campaigns weren't awful, they bordered on mediocrity and at times, childishly cliche' and odd, trying to desperately interwine historical events/characters into its plot. Ultimately, being a hardcore Age of Empires fan and a hardcore veteran of AoE2 & Mythology, AoE3 still captured my interest as an alternate RTS choice outside of my Starcraft/C&C sessions. 8.5/10 (Complete Collection), 8/10 - Vanilla, 7/10 - War Chiefs, 9/10 - Asian Dynasties.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 29602:
# Texto del Review: hard to get started with, not recommended for beginers
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 29938:
# Texto del Review:  I REALLY like this game i love the graphics, the story, and the puzzles. If you dont have it i think its up to you to get Broken Age. BUT i think you should get it if you if youre looking for video games to buy on steam.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 49932:
# Texto del Review: Waifu clicker9/11 - IGN
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 1
#
#
# Review 286:
# Texto del Review: for an incomplete game to provide this much creativity and fun. cant wait for full release .
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 47577:
# Texto del Review: It's a good game, hitboxes could use a little fine tuneing but aside from that this game works and runs quite well, It has good mechanics for both running, and hiding. Verdict - 8/10
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2
#
#
# Review 47152:
# Texto del Review: I used to love this game. Then i took a paid mod in the knee.
# Análisis de Sentimiento (0-Negativo, 1-Neutral, 2-Positivo): 2

# %% [markdown]
# Tras completar las tres etapas con ambas bibliotecas, ajustando los umbrales de puntuacion para clasificar los sentientos en las distintas categorias, llegamos a varias conclusiones importantes. Aunque ambas bibliotecas proporcionaron categorizaciones de sentimiento, observamos que NLTK demostró ser más consistente en sus puntuaciones de polaridad y categorizaciones de sentimiento en comparación con TextBlob. TextBlob mostró algunas discrepancias en la clasificación de revisiones que podrían considerarse negativas como positivas, y viceversa. En contraste, NLTK proporcionó puntuaciones de polaridad más coherentes y precisas, lo que lo convirtió en nuestra elección preferida para el análisis de sentimiento.

# %% [markdown]
# Procedemos a eliminar la columna 'reviews_review' de tu DataFrame data_reviews

# %%
data_reviews.drop('reviews_review', axis=1, inplace=True)

# %%
data_reviews
# Out:
#                      user_id  \
# 0          76561197970982479
# 1                    js41637
# 2                  evcentric
# 3                      doctr
# 4                  maplemage
# ...                      ...
# 58164     SKELETRONPRIMEISOP
# 58165      76561198141079508
# 58166            ShadowYT100
# 58167  bestcustomurlevermade
# 58168      76561198209894493
#
#                                                 user_url reviews_posted  \
# 0      http://steamcommunity.com/profiles/76561197970...     2011-11-05
# 1                   http://steamcommunity.com/id/js41637     2014-06-24
# 2                 http://steamcommunity.com/id/evcentric            NaN
# 3                     http://steamcommunity.com/id/doctr     2013-10-14
# 4                 http://steamcommunity.com/id/maplemage     2014-04-15
# ...                                                  ...            ...
# 58164    http://steamcommunity.com/id/SKELETRONPRIMEISOP     2014-08-15
# 58165  http://steamcommunity.com/profiles/76561198141...     2014-08-02
# 58166           http://steamcommunity.com/id/ShadowYT100     2015-07-31
# 58167  http://steamcommunity.com/id/bestcustomurlever...     2015-12-20
# 58168  http://steamcommunity.com/profiles/76561198209...            NaN
#
#        reviews_item_id                                  reviews_helpful  \
# 0                 1250                                   No ratings yet
# 1               251610  15 of 20 people (75%) found this review helpful
# 2               248820                                   No ratings yet
# 3               250320   2 of 2 people (100%) found this review helpful
# 4               211420  35 of 43 people (81%) found this review helpful
# ...                ...                                              ...
# 58164              440                                   No ratings yet
# 58165           304930                                   No ratings yet
# 58166           265630                                   No ratings yet
# 58167           304050                                   No ratings yet
# 58168              570     0 of 2 people (0%) found this review helpful
#
#        reviews_recommend        reviews_year  sentiment_analysis
# 0                   True                2011                   2
# 1                   True                2014                   2
# 2                   True  Dato no disponible                   2
# 3                   True                2013                   2
# 4                   True                2014                   1
# ...                  ...                 ...                 ...
# 58164               True                2014                   2
# 58165               True                2014                   2
# 58166               True                2015                   2
# 58167               True                2015                   2
# 58168              False  Dato no disponible                   0
#
# [58169 rows x 8 columns]

# %%
data_reviews['reviews_recommend'].value_counts()
# Out:
# True     51459
# False     6710
# Name: reviews_recommend, dtype: int64

# %%
data_reviews['sentiment_analysis'].value_counts()
# Out:
# 2    33758
# 1    17262
# 0     7149
# Name: sentiment_analysis, dtype: int64

# %% [markdown]
# # Carga del Conjunto de Datos Transformado
# En esta etapa, cargaremos el conjunto de datos transformado y depurado, el cual hemos nombrado "sentiment_analysis.csv". Este archivo refleja nuestro conjunto de datos preparado y optimizado para análisis y modelado de datos

# %%
# Especifica el nombre del archivo
nombre_del_archivo = 'data_reviews_sentiment_analysis.csv'

# Guarda el DataFrame en el archivo CSV
data_reviews.to_csv(nombre_del_archivo, index=False, encoding='utf-8')
print(f'Se ha guardado el archivo {nombre_del_archivo} en la misma carpeta.')
# Out:
# Se ha guardado el archivo data_reviews_sentiment_analysis.csv en la misma carpeta.
